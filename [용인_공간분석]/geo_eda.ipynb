# %%
# 기본
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import geopandas as gpd
from shapely.geometry import Polygon,LineString,Point
import fiona
import json

# 진행상황
from IPython.display import display
from tqdm import tqdm

# 경고제어
import warnings
warnings.filterwarnings('ignore')

# 폰트
import matplotlib.font_manager as fm
import matplotlib as mpl

mpl.rcParams['axes.unicode_minus']=False
path = 'malgun.ttf'
fontprop = fm.FontProperties(fname=path, size=9)

# 파일 저장.
import pickle

# 색깔.
import random

# %%
m=gpd.read_file('11.용인시_법정경계(시군구).geojson')

# %%
store=pd.read_csv('1.용인시_상권_정보.csv')
store=store.dropna()
display(store.isna().sum())
store.head()
# Out:
# 대분류코드       0
# 중분류코드       0
# 소분류코드       0
# 표준산업분류코드    0
# 표준산업분류명     0
# 행정동코드       0
# 행정동명        0
# 도로명주소       0
# 경도          0
# 위도          0
# dtype: int64
#   대분류코드 중분류코드   소분류코드 표준산업분류코드   표준산업분류명       행정동코드   행정동명  \
# 0     Q   Q09  Q09A10   I56211  일반유흥 주점업  4146551000  풍덕천1동
# 1     Q   Q01  Q01A08   I56111   한식 음식점업  4146551000  풍덕천1동
# 2     Q   Q01  Q01A01   I56111   한식 음식점업  4146352000    구갈동
# 3     Q   Q09  Q09A10   I56211  일반유흥 주점업  4146151000    중앙동
# 4     Q   Q10  Q10A01   I56111   한식 음식점업  4146359000    보정동
#
#                        도로명주소          경도         위도
# 0  경기도 용인시 수지구 풍덕천로139번길 6-5  127.096851  37.324611
# 1   경기도 용인시 수지구 풍덕천로190번길 23  127.102347  37.324553
# 2       경기도 용인시 기흥구 갈곡로7번길 8  127.128573  37.272405
# 3      경기도 용인시 처인구 금령로71번길 2  127.204204  37.235371
# 4         경기도 용인시 기흥구 죽전로 50  127.114245  37.320282

# %%
# data={}

# for idx in tqdm(store.표준산업분류명.unique()):
#     df=store[store.표준산업분류명==idx]
#     df['geometry']=store.apply(lambda row:Point([row['경도'],row['위도']]),axis=1)
#     df=gpd.GeoDataFrame(df[['geometry']],geometry='geometry')
#     data[idx]=df

# %%
# with open('categorical_store.pickle','wb') as f:
#     pickle.dump(data,f)

# %%
with open('categorical_store.pickle','rb') as f:
    cat_store=pickle.load(f)

for key in tqdm(cat_store.keys()):
    cat_store[key].crs={'init':'epsg:3174'}
# Out:
# 100%|██████████| 183/183 [00:03<00:00, 56.08it/s]

# %% [markdown]
# 분류명 따라 나누고 비춰보기
# 색깔 다시 봐보기

# %%
loads=gpd.read_file('9.용인시_도로명주소_도로.geojson')

# %%
# line to point
ltp={'geometry':[]}
for load in tqdm(loads['geometry']):
    for xy in load[0].coords:
        y,x=xy
        ltp['geometry'].append(Point(y,x))
ltp=gpd.GeoDataFrame(ltp,geometry='geometry')
display(ltp.head())
# Out:
# 100%|██████████| 5891/5891 [00:01<00:00, 3512.86it/s]
#                      geometry
# 0  POINT (127.12341 37.09031)
# 1  POINT (127.12340 37.09032)
# 2  POINT (127.12254 37.09227)
# 3  POINT (127.11936 37.09925)
# 4  POINT (127.11819 37.10182)

# %%
# 1도의 거리는 133km 1초의 거리는 37m. 100m 기준으로.
ltp_buf=gpd.GeoDataFrame({'geometry':ltp.buffer(1/120)})

# %%
# sigungu=gpd.read_file('12.용인시_법정경계(읍면동).geojson')
# sigungu.head()

# %% [markdown]
# ### 도로 커버 가능

# %%
ax=m.plot(figsize=(12,12), alpha=0.8,column='SIG_KOR_NM',color=['#beface','#54574f','#bfa978'],
          legend=True,legend_kwds={'bbox_to_anchor':(1.5,1),'prop':fontprop}) # 겹쳐서 안보인다.

ltp_buf.plot(ax=ax,color='#f74885') # 핑크 
loads.plot(ax=ax,color='black')
# sigungu.plot(ax=ax,column='EMD_KOR_NM') # 읍면동별 색깔 다름.
ax.set_title("경기도 용인시 지도", fontsize=20,fontproperties=fontprop)
ax.set_axis_off()

plt.show()

# %% [markdown]
# ### store 분포

# %%
# http://www.yongin.go.kr/estat/index.do 용인시 
# http://www.yongin.go.kr/user/bbs/BD_selectBbs.do?q_menu=&q_clCode=1&q_lwprtClCode=&q_searchKeyTy=sj___1002&q_searchVal=&q_category=&q_bbsCode=1030&q_bbscttSn=20201124113535298&q_currPage=1&q_sortName=&q_sortOrder=&
# 용인시 인구분포
df=m[:]
df['사업체수']=[19777,19666,13280]
df['종사자수']=[116045,148751,72720]
df['인구수']=[258335,440826,376309]
df['밀집도(#/area)']=df['사업체수']/df['geometry'].area
df
# Out:
#   SIG_CD SIG_KOR_NM                                           geometry   사업체수  \
# 0  41461     용인시처인구  MULTIPOLYGON (((127.10873 37.12385, 127.10874 ...  19777
# 1  41463     용인시기흥구  MULTIPOLYGON (((127.06526 37.26919, 127.06525 ...  19666
# 2  41465     용인시수지구  MULTIPOLYGON (((127.02966 37.37213, 127.02975 ...  13280
#
#      종사자수     인구수   밀집도(#/area)
# 0  116045  258335  4.164647e+05
# 1  148751  440826  2.367169e+06
# 2   72720  376309  3.101257e+06

# %%
# https://gits.gg.go.kr/gtdb/web/trafficDb/bus/TransitBusPass.do
# https://www.zamzar.com/uploadComplete.php?convertFile=xls&to=csv&session=03c9f38615564d1e3293c6db2c3748&email=false&tcs=Z75 

# 1번에서 얻고, 2번에서 바꾸고.

bus_12=pd.read_csv('TransitBusPass.csv',header=1,thousands=',')
bus=bus_12.loc[(bus_12['시간']=='주간')|(bus_12['시간']=='전일')].reset_index(drop=True)

bus['gu']=bus.지역.str.extract('([가-힣]+구)')

bus=bus.groupby('gu',as_index=False)['전체.2'].agg({'승하차':'sum'})
bus
# Out:
#     gu     승하차
# 0  기흥구  556014
# 1  수지구  826854
# 2  처인구  366580

# %%
df['승하차수']=[366580,556014,826854]
df
# Out:
#   SIG_CD SIG_KOR_NM                                           geometry   사업체수  \
# 0  41461     용인시처인구  MULTIPOLYGON (((127.10873 37.12385, 127.10874 ...  19777
# 1  41463     용인시기흥구  MULTIPOLYGON (((127.06526 37.26919, 127.06525 ...  19666
# 2  41465     용인시수지구  MULTIPOLYGON (((127.02966 37.37213, 127.02975 ...  13280
#
#      종사자수     인구수   밀집도(#/area)    승하차수
# 0  116045  258335  4.164647e+05  366580
# 1  148751  440826  2.367169e+06  556014
# 2   72720  376309  3.101257e+06  826854

# %%
chart=df[['사업체수','종사자수','인구수','밀집도(#/area)','승하차수']]

chart.index=['처인구','기흥구','수지구']
chart
# Out:
#       사업체수    종사자수     인구수   밀집도(#/area)    승하차수
# 처인구  19777  116045  258335  4.164647e+05  366580
# 기흥구  19666  148751  440826  2.367169e+06  556014
# 수지구  13280   72720  376309  3.101257e+06  826854

# %%
store['gu']=store['도로명주소'].str.extract('([가-힣]+구)')
gu_store=store.groupby(['gu'])['표준산업분류명'].value_counts().unstack(fill_value=0).T

# %%
gu_store['기흥구']=gu_store['기흥구']/gu_store['기흥구'].sum()*100
gu_store['처인구']=gu_store['처인구']/gu_store['처인구'].sum()*100
gu_store['수지구']=gu_store['수지구']/gu_store['수지구'].sum()*100

# %%
top10_gu_store=gu_store.sort_values(['기흥구','수지구','처인구'],ascending=False)[:10]

# %%
top10_gu_store.index
# Out:
# Index(['한식 음식점업', '일반 교과 학원', '비알콜 음료점업', '부동산 자문 및 중개업', '셔츠 및 기타 의복 소매업',
#        '두발미용업', '분식 및 김밥 전문점', '외국어학원', '예술 학원', '기타 주점업'],
#       dtype='object', name='표준산업분류명')

# %%
top10_gu_store_cumsum=np.cumsum(top10_gu_store)

# %%
def cumsum_bar(height,bottom,ax,label):
    ax.bar(x=['기흥구','수지구','처인구'],height=height,bottom=bottom,label=label)

# %%
fig,ax=plt.subplots(1,1,figsize=(8,6),dpi=150)

cumsum_bar(height=top10_gu_store.loc['한식 음식점업'].values,
           bottom=0,
           ax=ax,label='한식 음식점업')
cumsum_bar(height=top10_gu_store.loc['일반 교과 학원'].values,
           bottom=top10_gu_store_cumsum.loc['한식 음식점업'].values,
           ax=ax,label='일반 교과 학원')
cumsum_bar(height=top10_gu_store.loc['비알콜 음료점업'].values,
           bottom=top10_gu_store_cumsum.loc['일반 교과 학원'].values,
           ax=ax,label='비알콜 음료점업')
cumsum_bar(height=top10_gu_store.loc['부동산 자문 및 중개업'].values,
           bottom=top10_gu_store_cumsum.loc['비알콜 음료점업'].values,
           ax=ax,label='부동산 자문 및 중개업')
cumsum_bar(height=top10_gu_store.loc['셔츠 및 기타 의복 소매업'].values,
           bottom=top10_gu_store_cumsum.loc['부동산 자문 및 중개업'].values,
           ax=ax,label='셔츠 및 기타 의복 소매업')
cumsum_bar(height=top10_gu_store.loc['두발미용업'].values,
           bottom=top10_gu_store_cumsum.loc['셔츠 및 기타 의복 소매업'].values,
           ax=ax,label='두발미용업')
cumsum_bar(height=top10_gu_store.loc['분식 및 김밥 전문점'].values,
           bottom=top10_gu_store_cumsum.loc['두발미용업'].values,
           ax=ax,label='분식 및 김밥 전문점')
cumsum_bar(height=top10_gu_store.loc['외국어학원'].values,
           bottom=top10_gu_store_cumsum.loc['분식 및 김밥 전문점'].values,
           ax=ax,label='외국어학원')
cumsum_bar(height=top10_gu_store.loc['예술 학원'].values,
           bottom=top10_gu_store_cumsum.loc['외국어학원'].values,
           ax=ax,label='예술 학원')
cumsum_bar(height=top10_gu_store.loc['기타 주점업'].values,
           bottom=top10_gu_store_cumsum.loc['예술 학원'].values,
           ax=ax,label='기타 주점업')

ax.set_xticks(range(3))
ax.set_xticklabels(['기흥구','수지구','처인구'],fontproperties=fontprop)
ax.annotate(f"{top10_gu_store.round(2)}",xy=(2.45,0.6),font=fontprop)
ax.legend(bbox_to_anchor=(1.04,1),fontsize=7,prop=fontprop)
ax.set_title("구별 Top 10 사업체 수",fontsize=15,loc='left',y=1.1,fontproperties=fontprop)

plt.suptitle("비율로 준비했기 때문에 Top10이 차지하는 비율의 차이가 있다.\n        수지구는 교육위주의 지역이고, 처인구는 음식 및 생활과 관련이 있다.",
             x=0.405,y=0.95,fontproperties=fontprop)
plt.show()

# %%
# 기흥구와 처인구에 비해 수지구는 포화상태다.
display(chart.style.background_gradient(cmap='Blues'))
# Out:
# <style  type="text/css" >
# #T_b4d33cf8_5b9f_11eb_aae9_0a580a810a0drow0_col0,#T_b4d33cf8_5b9f_11eb_aae9_0a580a810a0drow1_col1,#T_b4d33cf8_5b9f_11eb_aae9_0a580a810a0drow1_col2,#T_b4d33cf8_5b9f_11eb_aae9_0a580a810a0drow2_col3,#T_b4d33cf8_5b9f_11eb_aae9_0a580a810a0drow2_col4{
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }#T_b4d33cf8_5b9f_11eb_aae9_0a580a810a0drow0_col1{
#             background-color:  #549fcd;
#             color:  #000000;
#         }#T_b4d33cf8_5b9f_11eb_aae9_0a580a810a0drow0_col2,#T_b4d33cf8_5b9f_11eb_aae9_0a580a810a0drow0_col3,#T_b4d33cf8_5b9f_11eb_aae9_0a580a810a0drow0_col4,#T_b4d33cf8_5b9f_11eb_aae9_0a580a810a0drow2_col0,#T_b4d33cf8_5b9f_11eb_aae9_0a580a810a0drow2_col1{
#             background-color:  #f7fbff;
#             color:  #000000;
#         }#T_b4d33cf8_5b9f_11eb_aae9_0a580a810a0drow1_col0{
#             background-color:  #083471;
#             color:  #f1f1f1;
#         }#T_b4d33cf8_5b9f_11eb_aae9_0a580a810a0drow1_col3{
#             background-color:  #2676b8;
#             color:  #000000;
#         }#T_b4d33cf8_5b9f_11eb_aae9_0a580a810a0drow1_col4{
#             background-color:  #8fc2de;
#             color:  #000000;
#         }#T_b4d33cf8_5b9f_11eb_aae9_0a580a810a0drow2_col2{
#             background-color:  #3c8cc3;
#             color:  #000000;
#         }</style><table id="T_b4d33cf8_5b9f_11eb_aae9_0a580a810a0d" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >사업체수</th>        <th class="col_heading level0 col1" >종사자수</th>        <th class="col_heading level0 col2" >인구수</th>        <th class="col_heading level0 col3" >밀집도(#/area)</th>        <th class="col_heading level0 col4" >승하차수</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b4d33cf8_5b9f_11eb_aae9_0a580a810a0dlevel0_row0" class="row_heading level0 row0" >처인구</th>
#                         <td id="T_b4d33cf8_5b9f_11eb_aae9_0a580a810a0drow0_col0" class="data row0 col0" >19777</td>
#                         <td id="T_b4d33cf8_5b9f_11eb_aae9_0a580a810a0drow0_col1" class="data row0 col1" >116045</td>
#                         <td id="T_b4d33cf8_5b9f_11eb_aae9_0a580a810a0drow0_col2" class="data row0 col2" >258335</td>
#                         <td id="T_b4d33cf8_5b9f_11eb_aae9_0a580a810a0drow0_col3" class="data row0 col3" >416464.670551</td>
#                         <td id="T_b4d33cf8_5b9f_11eb_aae9_0a580a810a0drow0_col4" class="data row0 col4" >366580</td>
#             </tr>
#             <tr>
#                         <th id="T_b4d33cf8_5b9f_11eb_aae9_0a580a810a0dlevel0_row1" class="row_heading level0 row1" >기흥구</th>
#                         <td id="T_b4d33cf8_5b9f_11eb_aae9_0a580a810a0drow1_col0" class="data row1 col0" >19666</td>
#                         <td id="T_b4d33cf8_5b9f_11eb_aae9_0a580a810a0drow1_col1" class="data row1 col1" >148751</td>
#                         <td id="T_b4d33cf8_5b9f_11eb_aae9_0a580a810a0drow1_col2" class="data row1 col2" >440826</td>
#                         <td id="T_b4d33cf8_5b9f_11eb_aae9_0a580a810a0drow1_col3" class="data row1 col3" >2367168.621877</td>
#                         <td id="T_b4d33cf8_5b9f_11eb_aae9_0a580a810a0drow1_col4" class="data row1 col4" >556014</td>
#             </tr>
#             <tr>
#                         <th id="T_b4d33cf8_5b9f_11eb_aae9_0a580a810a0dlevel0_row2" class="row_heading level0 row2" >수지구</th>
#                         <td id="T_b4d33cf8_5b9f_11eb_aae9_0a580a810a0drow2_col0" class="data row2 col0" >13280</td>
#                         <td id="T_b4d33cf8_5b9f_11eb_aae9_0a580a810a0drow2_col1" class="data row2 col1" >72720</td>
#                         <td id="T_b4d33cf8_5b9f_11eb_aae9_0a580a810a0drow2_col2" class="data row2 col2" >376309</td>
#                         <td id="T_b4d33cf8_5b9f_11eb_aae9_0a580a810a0drow2_col3" class="data row2 col3" >3101256.777939</td>
#                         <td id="T_b4d33cf8_5b9f_11eb_aae9_0a580a810a0drow2_col4" class="data row2 col4" >826854</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ### 표준산업분류명 넣기.

# %%
ax=df.plot(figsize=(11,11),column='SIG_KOR_NM',color=['#88949e','#687178','#b4d9fa'],alpha=0.6)

# label에 원하는 표준산업분류명 넣기.
cat_store['기타 갬블링 및 베팅업'].plot(ax=ax, marker='v', color='#fd0750', label='기타 갬블링 및 베팅업')

ax.set_title("Gyeonggi", fontsize=20)
ax.set_axis_off()

ax.legend()
plt.show()
